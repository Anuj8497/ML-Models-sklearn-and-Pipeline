# %%
import pandas as pd

# %%
data = pd.read_csv('data_churn.csv')

# %%
data
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df_yes_churn = data[data['Churn'] == 'Yes']
df_no_churn = data[data['Churn'] == 'No']

# %%
#undersample the majority class
df_no_sample = df_no_churn.sample(1869)

# %%
undersampled_balanced_data = pd.concat([df_no_sample,df_yes_churn],axis = 0)

# %%
# oversample the minority class
df_yes_sample = df_yes_churn.sample(5174,replace = True)
df_yes_sample.shape
# Out:
# (5174, 21)

# %%
df_yes_sample
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 6227  2842-JTCCU    Male              0      No         No       2
# 693   2276-YDAVZ  Female              0      No         No       3
# 2428  2519-FAKOD    Male              0      No        Yes      38
# 3334  0337-CNPZE  Female              0      No         No      41
# 4265  2632-UCGVD    Male              1     Yes         No      66
# ...          ...     ...            ...     ...        ...     ...
# 865   3671-SHRSP    Male              0     Yes         No       4
# 64    5698-BQJOH  Female              0      No         No       9
# 6064  7568-PODML    Male              0      No         No       1
# 3888  6086-ESGRL  Female              0      No         No       1
# 5062  2911-UREFD  Female              0     Yes         No      39
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 6227          Yes                No             DSL             No  ...
# ...

# %%
df_no_churn.shape
# Out:
# (5174, 21)

# %%
df_no_churn
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 3     7795-CFOCW    Male              0      No         No      45
# 6     1452-KIOVK    Male              0      No        Yes      22
# 7     6713-OKOMC  Female              0      No         No      10
# ...          ...     ...            ...     ...        ...     ...
# 7037  2569-WGERO  Female              0      No         No      72
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 0              No  No phone service             DSL                   No  ...
# ...

# %%
oversampled_balanced_data = pd.concat([df_no_churn,df_yes_sample],axis = 0)

# %%
# SMOTE
#!pip install imblearn
from imblearn.over_sampling import SMOTE

# %%
smote = SMOTE(sampling_strategy = 'minority')

# %%
from sklearn.model_selection import train_test_split

# %%
X = data.drop('Churn',axis = 1)
y = data['Churn']

# %%
y.value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
x_sm ,y_sm = smote.fit_sample(X,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-51bf49965419> in <module>
# ----> 1 x_sm ,y_sm = smote.fit_sample(X,y)
#
# ~\Anaconda3\lib\site-packages\imblearn\base.py in fit_resample(self, X, y)
#      75         check_classification_targets(y)
#      76         arrays_transformer = ArraysTransformer(X, y)
# ---> 77         X, y, binarize_y = self._check_X_y(X, y)
#      78
#      79         self.sampling_strategy_ = check_sampling_strategy(
#
# ~\Anaconda3\lib\site-packages\imblearn\base.py in _check_X_y(self, X, y, accept_sparse)
#     133         y, binarize_y = check_target_type(y, indicate_one_vs_all=True)
#     134         X, y = self._validate_data(
# --> 135             X, y, reset=True, accept_sparse=accept_sparse
#     136         )
#     137         return X, y, binarize_y
#
# ...

# %%
# Ensemble method with undersampling

# %%
df_yes_churn.shape,df_no_churn.shape
# Out:
# ((1869, 21), (5174, 21))

# %%
5174/1869 #2.7683253076511503
# Out:
# 2.7683253076511503

# %%
# Divide the dataframe containing the no churned customers into three batches
temp = df_no_churn[:1869]  # from not churned get first 1869 records

# %%
new = pd.concat([temp,df_yes_churn],axis = 0)

# %%
temp1 = df_no_churn[1869:3738]

# %%
new1 = pd.concat([temp1,df_yes_churn],axis = 0)
